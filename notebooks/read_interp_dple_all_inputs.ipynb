% %% [markdown]
% Read CESM DPLE netcdfs

% %%
clear all
close all

fpath='/glade/scratch/kristenk/fish-offline/';

% %% [markdown]
% Display netcdf contents for zooC as example

% %%
ncdisp([fpath 'DPLE-FIESTY-forcing_zooC_150m_nodriftcorr.nc'])
% Out:
% Source:
%            /glade/scratch/kristenk/fish-offline/DPLE-FIESTY-forcing_zooC_150m_nodriftcorr.nc
% Format:
%            netcdf4
% Dimensions:
%            nlat = 384
%            nlon = 320
%            M    = 40
%            L    = 122
%            Y    = 64
% Variables:
%     TLONG
%            Size:       320x384
%            Dimensions: nlon,nlat
%            Datatype:   double
%            Attributes:
%                        _FillValue    = 9.969209968386869e+36
%                        units         = 'degrees_east'
%                        long_name     = 'array of t-grid longitudes'
%                        missing_value = 9.969209968386869e+36
%     TLAT
%            Size:       320x384
%            Dimensions: nlon,nlat
%            Datatype:   double
%            Attributes:
%                        _FillValue    = 9.969209968386869e+36
%                        units         = 'degrees_north'
%                        long_name     = 'array of t-grid latitudes'
%                        missing_value = 9.969209968386869e+36
%     M
%            Size:       40x1
%            Dimensions: M
%            Datatype:   int64
%     L
%            Size:       122x1
%            Dimensions: L
%            Datatype:   int64
%     Y
%            Size:       64x1
%            Dimensions: Y
%            Datatype:   int64
%     zooC_150m
%            Size:       320x384x122x40x64
%            Dimensions: nlon,nlat,L,M,Y
%            Datatype:   single
%            Attributes:
%                        _FillValue  = NaN
%                        units       = 'mmol/m^3 cm'
%                        long_name   = 'Zooplankton biomass depth integral'
%                        coordinates = 'TLONG TLAT time'

% %% [markdown]
% # Loop over initialization years

% %% [markdown]
% Read in that year of FOSI

% %%
% Mat file of FOSI current year + 9 yrs

% Pelagic temperature
ncid = netcdf.open([fpath 'DPLE-FIESTY-forcing_TEMP_150m_nodriftcorr.nc'],'NC_NOWRITE');
[ndims,nvars,ngatts,unlimdimid] = netcdf.inq(ncid);
for i = 1:(nvars-1)
    varname = netcdf.inqVar(ncid, i-1);
    eval([ varname ' = netcdf.getVar(ncid,i-1);']);
    eval([ varname '(' varname ' == 9.969209968386869e+36) = NaN;']);
end
[ni,nj] = size(TLONG);
whos M L Y

%for yr=1:length(Y);
    mem = 1; %1:length(M);
    y = length(Y); %1:length(Y);
    iy = Y(y); %1:length(Y);
% Out:
%   Name        Size            Bytes  Class    Attributes
%
%   L         122x1               976  int64
%   M          40x1               320  int64
%   Y          64x1               512  int64

% %% [markdown]
% ## Loop over ensemble members

% %% [markdown]
% Read one forecast for one ensemble member for the first lead year of temp and det

% %%
% Pelagic temperature
ncid = netcdf.open([fpath 'DPLE-FIESTY-forcing_TEMP_150m_nodriftcorr.nc'],'NC_NOWRITE');
[ndims,nvars,ngatts,unlimdimid] = netcdf.inq(ncid);
for n = nvars
    varname = netcdf.inqVar(ncid, n-1);
    eval([ varname ' = netcdf.getVar(ncid,n-1, [0,0,0,mem-1,iy-1],[ni,nj,length(L),1,1]);']);
    eval([ varname '(' varname ' == 9.969209968386869e+36) = NaN;']);
end
netcdf.close(ncid);

% Bottom temperature
ncid = netcdf.open([fpath 'DPLE-FIESTY-forcing_TEMP_bottom_nodriftcorr.nc'],'NC_NOWRITE');
[ndims,nvars,ngatts,unlimdimid] = netcdf.inq(ncid);
for i = 1:(nvars-1)
    varname = netcdf.inqVar(ncid, i-1);
    eval([ varname ' = netcdf.getVar(ncid,i-1);']);
    eval([ varname '(' varname ' == 9.969209968386869e+36) = NaN;']);
end
[ni,nj] = size(TLONG);
for n = nvars
    varname = netcdf.inqVar(ncid, n-1);
    eval([ varname ' = netcdf.getVar(ncid,n-1, [0,0,0,mem-1,iy-1],[ni,nj,length(L),1,1]);']);
    eval([ varname '(' varname ' == 9.969209968386869e+36) = NaN;']);
end
netcdf.close(ncid);

%Bottom detritus
ncid = netcdf.open([fpath 'DPLE-FIESTY-forcing_POC_FLUX_IN_bottom_nodriftcorr.nc'],'NC_NOWRITE');
[ndims,nvars,ngatts,unlimdimid] = netcdf.inq(ncid);
for i = 1:(nvars-1)
    varname = netcdf.inqVar(ncid, i-1);
    eval([ varname ' = netcdf.getVar(ncid,i-1);']);
    eval([ varname '(' varname ' == 9.969209968386869e+36) = NaN;']);
end
[ni,nj] = size(TLONG);
for n = nvars
    varname = netcdf.inqVar(ncid, n-1);
    eval([ varname ' = netcdf.getVar(ncid,n-1, [0,0,0,mem-1,iy-1],[ni,nj,length(L),1,1]);']);
    eval([ varname '(' varname ' == 9.969209968386869e+36) = NaN;']);
end
netcdf.close(ncid);

% %% [markdown]
% Read one forecast for one ensemble member for the first lead year of spC

% %%
ncid = netcdf.open([fpath 'DPLE-FIESTY-forcing_spC_150m_nodriftcorr.nc'],'NC_NOWRITE');
[ndims,nvars,ngatts,unlimdimid] = netcdf.inq(ncid);
for i = 1:(nvars-1)
    varname = netcdf.inqVar(ncid, i-1);
    eval([ varname ' = netcdf.getVar(ncid,i-1);']);
    eval([ varname '(' varname ' == 9.969209968386869e+36) = NaN;']);
end
[ni,nj] = size(TLONG);
for n = nvars
    varname = netcdf.inqVar(ncid, n-1);
    eval([ varname ' = netcdf.getVar(ncid,n-1, [0,0,0,mem-1,iy-1],[ni,nj,length(L),1,1]);']);
    eval([ varname '(' varname ' == 9.969209968386869e+36) = NaN;']);
end
netcdf.close(ncid);

% %% [markdown]
% Read one forecast for one ensemble member for the first lead year chunk of diatC

% %%
ncid = netcdf.open([fpath 'DPLE-FIESTY-forcing_diatC_150m_nodriftcorr.nc'],'NC_NOWRITE');
[ndims,nvars,ngatts,unlimdimid] = netcdf.inq(ncid);
for i = 1:(nvars-1)
    varname = netcdf.inqVar(ncid, i-1);
    eval([ varname ' = netcdf.getVar(ncid,i-1);']);
    eval([ varname '(' varname ' == 9.969209968386869e+36) = NaN;']);
end
for n = nvars
    varname = netcdf.inqVar(ncid, n-1);
    eval([ varname ' = netcdf.getVar(ncid,n-1,[0,0,0,mem-1,iy-1],[ni,nj,length(L),1,1]);']);
    eval([ varname '(' varname ' == 9.969209968386869e+36) = NaN;']);
end
netcdf.close(ncid);

ncid = netcdf.open([fpath 'DPLE-FIESTY-forcing_diazC_150m_nodriftcorr.nc'],'NC_NOWRITE');
[ndims,nvars,ngatts,unlimdimid] = netcdf.inq(ncid);
for i = 1:(nvars-1)
    varname = netcdf.inqVar(ncid, i-1);
    eval([ varname ' = netcdf.getVar(ncid,i-1);']);
    eval([ varname '(' varname ' == 9.969209968386869e+36) = NaN;']);
end
for n = nvars
    varname = netcdf.inqVar(ncid, n-1);
    eval([ varname ' = netcdf.getVar(ncid,n-1,[0,0,0,mem-1,iy-1],[ni,nj,length(L),1,1]);']);
    eval([ varname '(' varname ' == 9.969209968386869e+36) = NaN;']);
end
netcdf.close(ncid);

% %% [markdown]
% Read one forecast for one ensemble member for the first lead year of zooC and Loss

% %%
% Zooplankton
ncid = netcdf.open([fpath 'DPLE-FIESTY-forcing_zooC_150m_nodriftcorr.nc'],'NC_NOWRITE');
[ndims,nvars,ngatts,unlimdimid] = netcdf.inq(ncid);
for i = 1:(nvars-1)
    varname = netcdf.inqVar(ncid, i-1);
    eval([ varname ' = netcdf.getVar(ncid,i-1);']);
    eval([ varname '(' varname ' == 9.969209968386869e+36) = NaN;']);
end
for n = nvars
    varname = netcdf.inqVar(ncid, n-1);
    %eval([ varname ' = netcdf.getVar(ncid,i-1);']);
    %zmeso = netcdf.getVar(ncid,n-1, [0,0,0,runs(1)-1],[360 180 length(z200) length(runs)]);
    eval([ varname ' = netcdf.getVar(ncid,n-1,[0,0,0,mem-1,iy-1],[ni,nj,length(L),1,1]);']);
    eval([ varname '(' varname ' == 9.969209968386869e+36) = NaN;']);
end
netcdf.close(ncid);

% Loss
ncid = netcdf.open([fpath 'DPLE-FIESTY-forcing_zoo_loss_150m_nodriftcorr.nc'],'NC_NOWRITE');
[ndims,nvars,ngatts,unlimdimid] = netcdf.inq(ncid);
for i = 1:(nvars-1)
    varname = netcdf.inqVar(ncid, i-1);
    eval([ varname ' = netcdf.getVar(ncid,i-1);']);
    eval([ varname '(' varname ' == 9.969209968386869e+36) = NaN;']);
end
for n = nvars
    varname = netcdf.inqVar(ncid, n-1);
    %eval([ varname ' = netcdf.getVar(ncid,i-1);']);
    %zmeso = netcdf.getVar(ncid,n-1, [0,0,0,runs(1)-1],[360 180 length(z200) length(runs)]);
    eval([ varname ' = netcdf.getVar(ncid,n-1,[0,0,0,mem-1,iy-1],[ni,nj,length(L),1,1]);']);
    eval([ varname '(' varname ' == 9.969209968386869e+36) = NaN;']);
end
netcdf.close(ncid);

% %%
% Doubles and nans
TEMP_150m = double(TEMP_150m); 
TEMP_bottom = double(TEMP_bottom); 
POC_FLUX_IN_bottom = double(POC_FLUX_IN_bottom); 
zooC_150m = double(zooC_150m); 
zoo_loss_150m = double(zoo_loss_150m); 
diatC_150m = double(diatC_150m);
diazC_150m = double(diazC_150m);
spC_150m = double(spC_150m); 

POC_FLUX_IN_bottom(POC_FLUX_IN_bottom >= 9.9e+36) = nan;
zooC_150m(zooC_150m >= 9.9e+36) = nan;
zoo_loss_150m(zoo_loss_150m >= 9.9e+36) = nan;

% %% [markdown]
% Test that all vars same orientation

% %%
% test that all same orientation
test1 = squeeze(TEMP_150m(:,:,20));
test2 = squeeze(TEMP_bottom(:,:,20));
test3 = squeeze(zooC_150m(:,:,20));
test4 = squeeze(zoo_loss_150m(:,:,20));
test5 = squeeze(POC_FLUX_IN_bottom(:,:,20));
% test6 = mask;

figure
subplot(2,3,1)
pcolor(test1)
shading flat
colorbar
subplot(2,3,2)
pcolor(test2)
shading flat
colorbar
title('FOSI')
subplot(2,3,3)
pcolor(test5)
shading flat
colorbar
subplot(2,3,4)
pcolor(test3)
shading flat
colorbar
subplot(2,3,5)
pcolor(test4)
shading flat
colorbar
% subplot(2,3,6)
% pcolor(mask)
% shading flat
% colorbar

test11 = squeeze(TEMP_150m(:,:,20));
test12 = squeeze(TEMP_bottom(:,:,20));
test13 = squeeze(zooC_150m(:,:,20));
test14 = squeeze(zoo_loss_150m(:,:,20));
test15 = squeeze(POC_FLUX_IN_bottom(:,:,20));

figure
subplot(2,3,1)
pcolor(test11)
shading flat
colorbar
subplot(2,3,2)
pcolor(test12)
shading flat
colorbar
title('DPLE')
subplot(2,3,3)
pcolor(test15)
shading flat
colorbar
subplot(2,3,4)
pcolor(test13)
shading flat
colorbar
subplot(2,3,5)
pcolor(test14)
shading flat
colorbar

% %% [markdown]
% Calc large fraction of zoop from small and large phyto

% %%
% fraction large phyto -> frac large zoo
whos diazC_150m
fracL = diatC_150m ./ (diatC_150m + spC_150m + diazC_150m);
LzooC_150m = fracL .* zooC_150m;
Lzoo_loss_150m = fracL .* zoo_loss_150m;

LzooC_150m(LzooC_150m<0) = 0.0;
Lzoo_loss_150m(Lzoo_loss_150m<0) = 0.0;

clear diatC_150m spC_150m zooC_150m zoo_loss_150m diazC_150m
% Out:
%   Name              Size                     Bytes  Class     Attributes
%
%   diazC_150m      320x384x122            119930880  double

% %% [markdown]
% Time period for interpolation

% %%
mos = length(L);
mstart = 1:12:mos;
mend = 12:12:mos;
nyrs = mos/12
yrs = 1:nyrs;

Tdays=1:365;
Time=Tdays(15:30:end);
% Out:
% nyrs =
%
%    10.1667

% %% [markdown]
% Load griddata and check water cells

% %%
%pwd
Cdir = '/glade/u/home/cpetrik/fish-offline/MatFEISTY/input_files/';
load([Cdir 'gridspec_POP_gx1v6_noSeas.mat'],'mask');

test7 = squeeze(LzooC_150m(:,:,20));
test6 = mask;

figure
subplot(2,2,1)
pcolor(test7)
shading flat
colorbar
subplot(2,2,2)
pcolor(mask)
shading flat
colorbar

% %% [markdown]
% Daily interpolation, includes unit conversion

% %%
y=1;
yr = yrs(y);
['Data_cesm_dple_daily_M',num2str(mem),'_Y',num2str(iy),'_',num2str(yr),'.mat']
% Out:
% ans =
%
%     'Data_cesm_dple_daily_M1_Y64_1.mat'

% %%
spath = '/glade/scratch/cpetrik/fish-offline/dailies/';

for y = 1:nyrs
    yr = yrs(y)
    
    if y==1
        range = mstart(y):(mend(y)+1);
        Time=15:30:395;
    elseif y==nyrs
        range = (mstart(y)-1):mend(y);
        Time=-15:30:365;
    else
        range = (mstart(y)-1):(mend(y)+1);
        Time=-15:30:395;
    end
    
    % months of interest
    Tp  = (TEMP_150m(:,:,range));
    Tb  = (TEMP_bottom(:,:,range));
    Zm  = (LzooC_150m(:,:,range));
    dZm = (Lzoo_loss_150m(:,:,range));
    det = (POC_FLUX_IN_bottom(:,:,range));
    
    % index of water cells
    [ni,nj,nt] = size(LzooC_150m);
    %WID = find(~isnan(mask));  % spatial index of water cells includes interior seas
    WID = find(~isnan(LzooC_150m(:,:,1)));    % spatial index of water cells excludes interior seas
    NID = length(WID);         % number of water cells
    
    % setup FEISTY data files
    D_Tp  = nan*zeros(NID,365);
    D_Tb  = nan*zeros(NID,365);
    D_Zm  = nan*zeros(NID,365);
    D_dZm  = nan*zeros(NID,365);
    D_det = nan*zeros(NID,365);
    
    %% interpolate to daily resolution
    for j = 1:NID
        % indexes
        [m,n] = ind2sub([ni,nj],WID(j)); % spatial index of water cell
        
        % pelagic temperature (in Celcius)
        Y = squeeze(Tp(m,n,:));
        yi = interp1(Time, Y, Tdays,'linear','extrap');
        D_Tp(j,:) = yi;
        
        % bottom temperature (in Celcius)
        Y = squeeze(Tb(m,n,:));
        yi = interp1(Time, Y, Tdays,'linear','extrap');
        D_Tb(j,:) = yi;
        
        % meso zoo: nmolC cm-2 to g(WW) m-2
        % 1e9 nmol in 1 mol C
        % 1e4 cm2 in 1 m2
        % 12.01 g C in 1 mol C
        % 1 g dry W in 9 g wet W (Pauly & Christiansen)
        Y = squeeze(Zm(m,n,:));
        yi = interp1(Time, Y, Tdays,'linear','extrap');
        D_Zm(j,:) = yi * 1e-9 * 1e4 * 12.01 * 9.0;
        
        % meso zoo mortality: nmolC cm-2 s-1 to g(WW) m-2 d-1
        % 1e9 nmol in 1 mol C
        % 1e4 cm2 in 1 m2
        % 12.01 g C in 1 mol C
        % 1 g dry W in 9 g wet W (Pauly & Christiansen)
        Y = squeeze(dZm(m,n,:));
        yi = interp1(Time, Y, Tdays,'linear','extrap');
        D_dZm(j,:) = yi * 1e-9 * 1e4 * 12.01 * 9.0 * 60 * 60 * 24;
        
        % detrital flux to benthos: nmolC cm-2 s-1 to g(WW) m-2 d-1
        % 1e9 nmol in 1 mol C
        % 1e4 cm2 in 1 m2
        % 12.01 g C in 1 mol C
        % 1 g dry W in 9 g wet W (Pauly & Christiansen)
        Y = squeeze(det(m,n,:));
        yi = interp1(Time, Y, Tdays,'linear','extrap');
        D_det(j,:) = yi * 1e-9 * 1e4 * 12.01 * 9.0 * 60 * 60 * 24;       
    end
    
    % Negative biomass or mortality loss from interp
    D_Zm(D_Zm<0) = 0.0;
    D_dZm(D_dZm<0) = 0.0;
    D_det(D_det<0) = 0.0;
    
    D_Zm(isnan(D_Zm)) = 0.0;
    D_dZm(isnan(D_dZm)) = 0.0;
    D_det(isnan(D_det)) = 0.0;
    
    ESM.Tp = D_Tp;
    ESM.Tb = D_Tb;
    ESM.Zm = D_Zm;
    ESM.dZm = D_dZm;
    ESM.det = D_det;
    
    % save
    save([spath 'Data_cesm_dple_daily_M',num2str(mem),'_Y',num2str(iy),'_',num2str(yr),'.mat'], 'ESM');   
    
end
% Out:
% yr =
%
%      1
%
%
% yr =
%
%      2
%
%
% yr =
%
%      3
%
%
% yr =
%
%      4
%
%
% yr =
%
%      5
%
%
% yr =
%
%      6
%
%
% yr =
%
%      7
%
%
% yr =
%
%      8
%
%
% yr =
%
%      9
%
%
% yr =
%
%     10
